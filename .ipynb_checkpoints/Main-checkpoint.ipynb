# %%
! pip install boto3
# Out:
# Requirement already satisfied: boto3 in c:\users\ericm\anaconda3\lib\site-packages (1.9.45)
# Requirement already satisfied: botocore<1.13.0,>=1.12.45 in c:\users\ericm\anaconda3\lib\site-packages (from boto3) (1.12.45)
# Requirement already satisfied: s3transfer<0.2.0,>=0.1.10 in c:\users\ericm\anaconda3\lib\site-packages (from boto3) (0.1.13)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in c:\users\ericm\anaconda3\lib\site-packages (from boto3) (0.9.3)
# Requirement already satisfied: docutils>=0.10 in c:\users\ericm\anaconda3\lib\site-packages (from botocore<1.13.0,>=1.12.45->boto3) (0.14)
# Requirement already satisfied: urllib3<1.25,>=1.20; python_version >= "3.4" in c:\users\ericm\anaconda3\lib\site-packages (from botocore<1.13.0,>=1.12.45->boto3) (1.23)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1; python_version >= "2.7" in c:\users\ericm\anaconda3\lib\site-packages (from botocore<1.13.0,>=1.12.45->boto3) (2.7.3)
# Requirement already satisfied: six>=1.5 in c:\users\ericm\anaconda3\lib\site-packages (from python-dateutil<3.0.0,>=2.1; python_version >= "2.7"->botocore<1.13.0,>=1.12.45->boto3) (1.11.0)
# You are using pip version 18.1, however version 19.0.2 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import requests
import json
import boto3

# %%
course_name = "Data Structures and Algorithms" # placeholder course name
course_name = course_name.replace(" ", "+")

url = 'https://sandbox.api.it.nyu.edu/course-catalog-exp/courses?course_title=' + course_name
headers = {'Authorization': 'Bearer b1c894d7-c394-38ca-9cb5-5b0969e101e0'}

req = requests.get(url, headers=headers)

# print(req.status_code)
# print(req.headers)
# print(req.text)
req = json.loads(req.text)
for i in range(len(req)):
    course_des = req[i]["course_descr"]
    print(course_des)
    
course_des1 = req[0]["course_descr"]
# Out:
# This course introduces data structures. Topics include program specifications and design; abstract data types; stacks, queues; dynamic storage allocation; sequential and linked implementation of stacks and queues; searching methods, sequential and binary; binary trees and general trees; hashing; computational complexity; sorting algorithms: selection sort, heap sort, mergesort and quicksort; comparison of sorting techniques and analysis. | Prerequisite: Graduate Standing, CS-GY 5303 *Online version available.
# This course presents an overview of fundamental data structures, which are commonplace in programming, as well as associated basic algorithms. Complexity analysis, linked lists, stacks, queues, trees, hashing, sorting, and basic graphs algorithms are covered. Core topics such as Floyd’s algorithm, minimum spanning tree algorithms, and branch and bound techniques are also covered. Practical lab exercises complement the lectures. The students further specialize and consolidate their knowledge through lab projects to demonstrate the operation and applications of various data structures.
# This course covers abstract data types and the implementation and use of standard data structures along with fundamental algorithms and the basics of algorithm analysis. Not open to students who have taken CS-UY 2134. | Prerequisite: CS-UY 1114 (C- or better); Corequisite: EX-UY 1
# This course introduces data structures. Topics include program specifications and design; abstract data types; stacks, queues; dynamic storage allocation; sequential and linked implementation of stacks and queues; searching methods, sequential and binary; binary trees and general trees; hashing; computational complexity; sorting algorithms: selection sort, heap sort, mergesort and quicksort; comparison of sorting techniques and analysis. | Prerequisite: Graduate Standing, CS-GY 5303 *Online version available.
# This course covers abstract data types and the implementation and use of standard data structures along with fundamental algorithms and the basics of algorithm analysis. Not open to students who have taken CS-UY 2134. | Prerequisite: CS-UY 1114 (C- or better); Corequisite: EX-UY 1
# This course introduces data structures. Topics include program specifications and design; abstract data types; stacks, queues; dynamic storage allocation; sequential and linked implementation of stacks and queues; searching methods, sequential and binary; binary trees and general trees; hashing; computational complexity; sorting algorithms: selection sort, heap sort, mergesort and quicksort; comparison of sorting techniques and analysis. | Prerequisite: Graduate Standing, CS-GY 5303 *Online version available.
# This course covers abstract data types and the implementation and use of standard data structures along with fundamental algorithms and the basics of algorithm analysis. Not open to students who have taken CS-UY 2134. | Prerequisite: CS-UY 1114 (C- or better); Corequisite: EX-UY 1

# %%
with open('rootkey.json', 'r') as json_file:
    rootkey = json.load(json_file)

# %%
comprehend = boto3.client(service_name='comprehend', region_name='us-east-1',
                          aws_access_key_id=rootkey['AWSAccessKeyId'],
                          aws_secret_access_key=rootkey['AWSSecretKey'])

print(json.dumps(comprehend.detect_key_phrases(Text=course_des1, LanguageCode='en')))
# Out:
# Calling DetectSentiment
# {"KeyPhrases": [{"Score": 0.9940035939216614, "Text": "This course", "BeginOffset": 0, "EndOffset": 11}, {"Score": 0.9833545088768005, "Text": "data structures", "BeginOffset": 23, "EndOffset": 38}, {"Score": 0.9714836478233337, "Text": "Topics", "BeginOffset": 40, "EndOffset": 46}, {"Score": 0.8610596656799316, "Text": "program specifications and design", "BeginOffset": 55, "EndOffset": 88}, {"Score": 0.9309594631195068, "Text": "abstract data types", "BeginOffset": 90, "EndOffset": 109}, {"Score": 0.8635700345039368, "Text": "stacks", "BeginOffset": 111, "EndOffset": 117}, {"Score": 0.9939448237419128, "Text": "queues", "BeginOffset": 119, "EndOffset": 125}, {"Score": 0.981532096862793, "Text": "dynamic storage allocation", "BeginOffset": 127, "EndOffset": 153}, {"Score": 0.9161036610603333, "Text": "sequential and linked implementation", "BeginOffset": 155, "EndOffset": 191}, {"Score": 0.9897733926773071, "Text": "stacks and queues", "BeginOffset": 195, "EndOffset": 212}, {"Score": 0.9323993921279907, "Text": "methods", "BeginOffset": 224, "EndOffset": 231}, {"Score": 0.8083667159080505, "Text": "sequential and binary", "BeginOffset": 233, "EndOffset": 254}, {"Score": 0.9534845948219299, "Text": "binary trees", "BeginOffset": 256, "EndOffset": 268}, {"Score": 0.9984956979751587, "Text": "general trees", "BeginOffset": 273, "EndOffset": 286}, {"Score": 0.7417882680892944, "Text": "hashing", "BeginOffset": 288, "EndOffset": 295}, {"Score": 0.9957850575447083, "Text": "computational complexity", "BeginOffset": 297, "EndOffset": 321}, {"Score": 0.8238749504089355, "Text": "sorting algorithms", "BeginOffset": 323, "EndOffset": 341}, {"Score": 0.9208953976631165, "Text": "selection sort", "BeginOffset": 343, "EndOffset": 357}, {"Score": 0.9061945676803589, "Text": "heap sort", "BeginOffset": 359, "EndOffset": 368}, {"Score": 0.5940983295440674, "Text": "mergesort", "BeginOffset": 370, "EndOffset": 379}, {"Score": 0.8912426233291626, "Text": "quicksort", "BeginOffset": 384, "EndOffset": 393}, {"Score": 0.9989904761314392, "Text": "comparison", "BeginOffset": 395, "EndOffset": 405}, {"Score": 0.96214759349823, "Text": "techniques and analysis", "BeginOffset": 417, "EndOffset": 440}, {"Score": 0.8814285397529602, "Text": "| Prerequisite", "BeginOffset": 442, "EndOffset": 456}, {"Score": 0.9669003486633301, "Text": "Graduate Standing", "BeginOffset": 458, "EndOffset": 475}, {"Score": 0.8797490000724792, "Text": "CS-GY 5303 *Online version", "BeginOffset": 477, "EndOffset": 503}], "ResponseMetadata": {"RequestId": "97730a08-3228-11e9-bebf-d99a8f84c034", "HTTPStatusCode": 200, "HTTPHeaders": {"date": "Sat, 16 Feb 2019 20:22:33 GMT", "content-type": "application/x-amz-json-1.1", "content-length": "2309", "connection": "keep-alive", "x-amzn-requestid": "97730a08-3228-11e9-bebf-d99a8f84c034"}, "RetryAttempts": 0}}
# End of DetectSentiment

# %%
keywords = json.loads(json.dumps(comprehend.detect_key_phrases(Text=course_des1, LanguageCode='en')))
for i in range(len(keywords["KeyPhrases"]) // 2):
    keyword = keywords["KeyPhrases"][i]["Text"]
    print(keyword)
# Out:
# This course
# data structures
# Topics
# program specifications and design
# abstract data types
# stacks
# queues
# dynamic storage allocation
# sequential and linked implementation
# stacks and queues
# methods
# sequential and binary
# binary trees

# %%
import requests

url = 'https://sandbox.api.it.nyu.edu/engage-exp/organizations'
headers = {'Authorization': 'Bearer b1c894d7-c394-38ca-9cb5-5b0969e101e0'}

req = requests.get(url, headers=headers)

print(req.status_code)
print(req.headers)
print(req.text)
# Out:
# 200
# {'Date': 'Sat, 16 Feb 2019 20:46:31 GMT', 'Content-Type': 'application/json;charset=UTF-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'X-RateLimit-Remaining': '19', 'X-RateLimit-Reset': '667', 'X-RateLimit-Limit': '20', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains;', 'X-Content-Type-Options': '1', 'X-Frame-Options': 'SAMEORIGIN', 'X-XSS-Protection': '1; mode=block'}
# [
#   {
#     "alternate_id": null,
#     "category": {
#       "id": 86074,
#       "name": "Religious Groups"
#     },
#     "created_at": "2013-01-02T22:21:34Z",
#     "description": "To help students turn to Christ and live for Christ.",
#     "id": 61739,
#     "is_disabled": false,
#     "keywords": "180, Fellowship, Christian, Small Groups, Purpose, Christianity",
#     "long_name": "180 Fellowship - All-University",
#     "member_count": 91,
#     "picture_url": "https://cdn0.orgsync.com/images/os-profile-pics/0f90be7f-c1f0-4a6b-8325-dfb35841ca69.png?cover=1&s=100",
#     "renewed_at": "2018-09-18T14:03:57Z",
#     "name": "180 Fellowship",
#     "umbrella_id": 53830,
#     "website_url": "http://www.nyu.edu/clubs/180fellowship"
#   },
#   {
#     "alternate_id": null,
#     "category": {
#       "id": 86160,
#       "name": "Department"
#     },
#     "created_at": "2017-10-11T15:03:11Z",
#     "description": null,
#     "id": 166774,
#     "is_disabled": false,
#     "keywords": "",
#     "long_name": "3 Year Pathway",
#     "member_count": 1,
#     "picture_url": "/assets/icons/portals/no_org_profile_100.png",
#     "renewed_at": null,
#     "name": "3YP",
#     "umbrella_id": 43082,
#     "website_url": null
#   },
#   {
#     "alternate_id": null,
#     "category": {
#       "id": 61111,
#       "name": "Service"
#     },
#     "created_at": "2016-02-01T16:37:02Z",
#     "description": "826NYC is a nonprofit organization dedicated to supporting students ages 6-18 with their creative and expository writing skills, and to helping teachers inspire their students to write. Our services are structured around our belief that great leaps in learning can happen with one-on-one attention and that strong writing skills are fundamental to future success.\r\n",
#     "id": 132459,
#     "is_disabled": false,
#     "keywords": "education, writing, creative writing, tutoring, workshops, field trips, publishing, authors, young authors, editing, superhero, superhero store, 826, books, arts education, english, Spanish, bilingual ",
#     "long_name": "826NYC",
#     "member_count": 1,
#     "picture_url": "https://cdn3.orgsync.com/images/os-profile-pics/pns2opz3lmlsm6b_150.jpg?cover=1&s=100",
#     "renewed_at": "2016-02-01T21:03:30Z",
#     "name": "826NYC",
#     "umbrella_id": 102322,
#     "website_url": "http://www.826nyc.org"
#   },
#   {
#     "alternate_id": null,
#     "category": {
#       "id": 86012,
#       "name": "Theater"
#     },
#     "created_at": "2018-10-19T01:27:25Z",
#     "description": null,
#     "id": 178043,
#     "is_disabled": false,
#     "keywords": "",
#     "long_name": "A Class Act",
#     "member_count": 1,
#     "picture_url": "/assets/icons/portals/no_org_profile_100.png",
#     "renewed_at": null,
#     "name": "ACA",
#     "umbrella_id": 116531,
#     "website_url": null
#   },
#   {
#     "alternate_id": null,
#     "category": {
#       "id": 61111,
#       "name": "Service"
#     },
#     "created_at": "2016-02-01T16:39:22Z",
#     "description": "Mission Statement: \r\n\"A Place for Kids is an educational institute providing quality cultural enrichment to support a child’s opportunity to succeed in the future.\"\r\n\r\nWe are a 47 year old organization founded in 1971 by a group of community minded college students from the City College of New York, who saw a need for low cost child care for low-income immigrant families in Chinatown.  APFK operate out of two public schools: PS 2 in Chinatown and PS 34 on the Lower East Side and offer an after-school program offering homework help and enrichment from 2:30 to 5:45 every day, as well as a 7 week summer program at PS 2.  \r\n\r\nOur programs have been sucessful due to the long standing relationships and collaborations with community based organizations and educational institutions such as: P.S. 2; P.S. 34; NYU; Confucius Institute of Pace University; BalaSole Dance Company; City-in-the Community - Chinatown/LES Soccer; and Asian American Youth Center and Asian Professionals for Excellence - McGraw-Hill. \r\n\r\nOur goal is to develop the minds and bodies of our children to their highest potential.  The on-going recruitment of volunteers, work-study, fieldwork and service work students from colleges and high schools enable us to continue providing individual and small attention to the needs of our children.\r\n\r\n ",
#     "id": 132461,
#     "is_disabled": false,
#     "keywords": "After-school program; tutoring;Children; Chinatown; Lower East Side",
#     "long_name": "A Place for Kids",
#     "member_count": 108,
#     "picture_url": "https://cdn3.orgsync.com/images/os-profile-pics/inrlxy9tl3a6bb1_150.jpg?cover=1&s=100",
#     "renewed_at": "2018-10-31T15:21:22Z",
#     "name": "A Place for Kids",
#     "umbrella_id": 102322,
#     "website_url": "http://www.aplaceforkidsny.org"
#   },
#   {
#     "alternate_id": null,
#     "category": {
#       "id": 69705,
#       "name": "Academic Achievement Program"
#     },
#     "created_at": "2015-09-16T14:55:13Z",
#     "description": "The Academic Achievement Program (AAP) is a multifaceted program that is designed to develop and enhance the academic and leadership potential of Black, Latino, Native American and other underrepresented students in the College of Arts and Science and greater New York University community.\r\n\r\nEvery year, AAP has provided a family atmosphere where students can make lasting friendships, seek refuge from classes and daily stresses and push their limits to achieve their potential.",
#     "id": 124162,
#     "is_disabled": false,
#     "keywords": "Academic Achievement Program, AAP, POISE",
#     "long_name": "Academic Achievement Program",
#     "member_count": 407,
#     "picture_url": "https://cdn4.orgsync.com/images/os-profile-pics/g0kewcj8o708fxr_150.jpg?cover=1&s=100",
#     "renewed_at": "2015-10-07T17:18:27Z",
#     "name": "AAP",
#     "umbrella_id": 106007,
#     "website_url": "http://aap.cas.nyu.edu/page/home"
#   },
#   {
#     "alternate_id": null,
#     "category": {
#       "id": 86160,
#       "name": "Department"
#     },
#     "created_at": "2017-06-29T15:50:16Z",
#     "description": null,
#     "id": 161948,
#     "is_disabled": false,
#     "keywords": "",
#     "long_name": "Academic Events",
#     "member_count": 4,
#     "picture_url": "/assets/icons/portals/no_org_profile_100.png",
#     "renewed_at": null,
#     "name": "Events",
#     "umbrella_id": 43082,
#     "website_url": null
#   },
#   {
#     "alternate_id": null,
#     "category": {
#       "id": 35743,
#       "name": "Clinical Interest Club"
#     },
#     "created_at": "2011-12-13T18:45:36Z",
#     "description": "Our mission is to promote scholarly activities on campus and provide resources for students interested in academic medicine. Our events include journal clubs led by distinguished faculty members, panels featuring students and faculty in academic medicine, professional development presentations, and student poster sessions.",
#     "id": 46243,
#     "is_disabled": false,
#     "keywords": "",
#     "long_name": "Academic Medicine Club",
#     "member_count": 92,
#     "picture_url": "https://cdn1.orgsync.com/images/os-profile-pics/6n6f0qaeet30sq_150.jpg?cover=1&s=100",
#     "renewed_at": "2016-12-12T22:40:54Z",
#     "name": "Academic Medicine",
#     "umbrella_id": 43082,
#     "website_url": "http://nyuschoolofmedicine.orgsync.com/org/academicmedicineclub46243"
#   },
#   {
#     "alternate_id": null,
#     "category": {
#       "id": 84943,
#       "name": "Health Professions and Clinical Interests "
#     },
#     "created_at": "2017-09-12T18:30:43Z",
#     "description": "Early exposure to Academy of General Dentistry (AGD) will allow dental students at NYU Dentistry to start building a relationship with general dentists while in school. AGD provides externship programs where students can connect with private practices, clinics or hospitals for a week in the summer and learn more about the life of a dentist in their practice settings. AGD student chapter can also help students gain continuing education credits while in school. These continuing education credits can then be recorded by the official AGD transcript and can be used toward obtaining a Fellowship Award with the AGD that will help a dentist to stand out. Other AGD services include podcasts about interviews and industry news, online case studies for reviews, advocacy for the general dentists, and even the AGD blog written by one of AGD members. In partnership with Dentists Advantage, AGD even offers a free year of professional liability insurance to its members during their first year of practice. The student chapter will also organize multiple Lunch and Learn events at 4-6pm for a variety of topics proposed by members each year. ",
#     "id": 164937,
#     "is_disabled": false,
#     "keywords": "Dentistry, General Dentistry, Dental education, College of Dentistry, New York University, NYUCD, Academy of General Dentistry, AGD, Continuing Education, Networking",
#     "long_name": "Academy of General Dentistry Student Chapter at NYU Dentistry",
#     "member_count": 134,
#     "picture_url": "https://cdn4.orgsync.com/images/os-profile-pics/v62lbji3qtoompb_150.jpg?cover=1&s=100",
#     "renewed_at": "2018-11-19T20:32:22Z",
#     "name": "AGD",
#     "umbrella_id": 86331,
#     "website_url": "https://www.facebook.com/groups/1965969396989993/"
#   },
#   {
#     "alternate_id": null,
#     "category": {
#       "id": 84943,
#       "name": "Health Professions and Clinical Interests "
#     },
#     "created_at": "2016-02-24T22:30:19Z",
#     "description": "MISSION STATEMENT\r\n\r\nWe want to enrich the professional experiences of health professionals graduating here at NEW YORK UNIVERSITY COLLEGE OF DENTISTRY (NYUCD) by starting this professional society that in the future, can associate closely with peers of other health professions.  This will be a tremendous experience that offers a lifetime membership into a professional society that will bring great benefits to all health practitioners in terms of education, patient referrals, treatment planning, etc. We will use this opportunity to expand our knowledge about the other professions and what role it can play in dentistry as well as educate others at our social events, seminars, symposiums, and workshops about our role in their professions and provide patient/practitioner referrals or advices to each other. There will be annual meetings amongst all ACE members from all participating schools. We will make it a priority to get to know each and every single member personally, and regard him or her as family. Our goal is to provide a platform where all health professionals can come together, enjoy each other’s company, help each other succeed by providing insight to our own personal experiences and treatments of our patients. We want other health professionals to understand more about dentistry and the role it can play in their related profession, and at the same time learn more about other professions.\r\n",
#     "id": 134810,
#     "is_disabled": false,
#     "keywords": "",
#     "long_name": "ACE - The Health Practitioner's Society",
#     "member_count": 34,
#     "picture_url": "https://cdn4.orgsync.com/images/os-profile-pics/07awt07qz9svopt_150.jpg?cover=1&s=100",
#     "renewed_at": "2018-06-08T18:03:05Z",
#     "name": "ACE",
#     "umbrella_id": 86331,
#     "website_url": null
#   },
#   {
#     "alternate_id": null,
#     "category": {
#       "id": 86069,
#       "name": "Activism and Advocacy"
#     },
#     "created_at": "2013-01-02T22:50:44Z",
#     "description": "NYU's chapter of the national organization, Active Minds, which works to advocate for mental health policy reform, a better public understanding of mental health issues, and the de-stigmatization of mental illness to help promote progress in the mental health industry and help those who suffer from mental health issues more easily seek out and access mental health care.",
#     "id": 61913,
#     "is_disabled": false,
#     "keywords": "mental health, advocacy, nonprofit, education, psychology, neural science, neuroscience, reform, social justice",
#     "long_name": "Active Minds - All-University",
#     "member_count": 351,
#     "picture_url": "https://cdn1.orgsync.com/images/os-profile-pics/w0w8qt3eofsw0l5_150.jpg?cover=1&s=100",
#     "renewed_at": "2018-07-12T13:55:43Z",
#     "name": "Active Minds",
#     "umbrella_id": 53830,
#     "website_url": "https://www.facebook.com/activemindsNYU/"
#   },
#   {
#     "alternate_id": null,
#     "category": {
#       "id": 54292,
#       "name": "Business"
#     },
#     "created_at": "2014-05-12T17:22:53Z",
#     "description": "Welcome to the Actuarial Society! We're a group passionate about the discipline of actuarial science. While under the Stern umbrella, we welcome students from all across the NYU community.\r\n\r\nOur aim is to provide students with an exposure to actuarial science as a discipline, and as a potential career opportunity. We help students with professional development, technical knowledge, as well as career related support. Most importantly, we are a tight-knit group and we invite everyone - regardless of career prospects - to learn more and join our actuarial community. \r\n\r\nOur meetings are every Wednesday from 12:30-1:45 in Tisch Hall, UC-19. All meetings are open to all students! Feel free to reach out to us at actrlsoc@stern.nyu.edu. Also feel free to reach out to Ashane (ashane.govind@stern.nyu.edu) or Lingtian (lingtian.meng@stern.nyu.edu) - this year's presidents - if you have any specific questions. Hope to see you at one of our events!",
#     "id": 86559,
#     "is_disabled": false,
#     "keywords": "Academic, Professional, Insurance, Consulting, Risk, Actuarial, Actuary, Exam P, Exam FM, Retirement, Property, Casualty, P&C, SOA, Casualty Actuary Society, Statistics, Calculus, Finance, Financial Mathematics, Probability, Pension, Pricing, Reserving, Modeling, Data Analysis, Analytics, ",
#     "long_name": "Actuarial Society",
#     "member_count": 213,
#     "picture_url": "https://cdn0.orgsync.com/images/os-profile-pics/na8ad27xw27z1zz_150.jpg?cover=1&s=100",
#     "renewed_at": "2018-05-02T01:26:12Z",
#     "name": "Actuarial",
#     "umbrella_id": 86332,
#     "website_url": "http://nyuactuarialsociety.weebly.com/"
#   },
#   {
#     "alternate_id": null,
#     "category": {
#       "id": 82645,
#       "name": "Academic"
#     },
#     "created_at": "2018-08-15T20:16:24Z",
#     "description": null,
#     "id": 174940,
#     "is_disabled": false,
#     "keywords": "",
#     "long_name": "Advanced Nursing Student Organization",
#     "member_count": 1,
#     "picture_url": "/assets/icons/portals/no_org_profile_100.png",
#     "renewed_at": null,
#     "name": "ANSO",
#     "umbrella_id": 162994,
#     "website_url": null
#   },
#   {
#     "alternate_id": null,
#     "category": {
#       "id": 86069,
#       "name": "Activism and Advocacy"
#     },
#     "created_at": "2013-01-02T22:34:25Z",
#     "description": "This is NYU's Against Child Trafficking (ACT) club, devoted to raising awareness on sex and labor trafficking. We are a close group of individuals that host engaging meetings that are driven by discussion. We aim to educate each other on all facets of modern day slavery, using documentaries, guest speakers, and news article. \r\n\r\nNew members always welcome to come and learn in an open environment. \r\n\r\nPlease e-mail us at act.club@nyu.edu to get info on the club room (changes week to week), events or any other questions! \r\n\r\nYou can also receive updates by following/liking us on Social Media. \r\nFacebook: https://www.facebook.com/ACTNYU/\r\nInstagram: https://www.instagram.com/actnyu/\r\nTwitter: https://twitter.com/nyu_act",
#     "id": 61870,
#     "is_disabled": false,
#     "keywords": "human trafficking, labor trafficking, sex trafficking, child trafficking, modern-day slavery",
#     "long_name": "Advocate Coalition (Against) Trafficking - All-University",
#     "member_count": 323,
#     "picture_url": "https://cdn2.orgsync.com/images/os-profile-pics/92c7n110a8e0pg_150.jpg?cover=1&s=100",
#     "renewed_at": "2018-09-24T19:15:36Z",
#     "name": "ACT",
#     "umbrella_id": 53830,
#     "website_url": "http://www.nyu.edu/clubs/act"
#   },
#   {
#     "alternate_id": null,
#     "category": {
#       "id": 84943,
#       "name": "Health Professions and Clinical Interests "
#     },
#     "created_at": "2016-02-24T22:31:36Z",
#     "description": "Our goal is to ignite the drive to be top aesthetic dentists amongst our members through community, education, philanthropy, INTEGRITY, and interdisciplinary action.",
#     "id": 134811,
#     "is_disabled": false,
#     "keywords": "Dentistry, Aesthetic, Esthetic, Cosmetic",
#     "long_name": "Aesthetics Society",
#     "member_count": 212,
#     "picture_url": "https://cdn1.orgsync.com/images/os-profile-pics/6987a625-b64d-4792-8b52-11b4d19cab3c.JPG?cover=1&s=100",
#     "renewed_at": "2018-08-18T16:32:56Z",
#     "name": "AESTHETICS",
#     "umbrella_id": 86331,
#     "website_url": null
#   },
#   {
#     "alternate_id": null,
#     "category": {
#       "id": 39675,
#       "name": "Cultural"
#     },
#     "created_at": "2013-01-02T22:09:42Z",
#     "description": "Afghan Students Association is the byproduct of undergraduate students united in the effort to preserve the experiences of past generations of Afghans and continually evolve our culture in the context of contemporary society. We are also devoted to reaching out to other diverse groups and/or individuals in support of mutual charitable causes and simultaneously promoting the cultures of an array of different groups. ",
#     "id": 61642,
#     "is_disabled": true,
#     "keywords": "afghanistan, nyu, muslim, students, washington square, afghan, new york city, country,",
#     "long_name": "Afghan Students Association - All-University",
#     "member_count": 39,
#     "picture_url": "https://cdn4.orgsync.com/images/os-profile-pics/i138qs58iz6xr13_150.jpg?cover=1&s=100",
#     "renewed_at": "2016-05-06T13:40:32Z",
#     "name": "Afghan Students Assocation",
#     "umbrella_id": 53830,
#     "website_url": "http://csals.orgsync.com/org/afghanstudentsassociationallsquare61642"
#   },
#   {
#     "alternate_id": null,
#     "category": {
#       "id": 86050,
#       "name": "Multicultural Groups"
#     },
#     "created_at": "2013-01-02T23:07:06Z",
#     "description": "African Heritage Month brings the NYU (New York University) community together in celebration of Africa and the Diaspora. Our purpose is to plan and sponsor events throughout the whole month of February including opening and closing ceremonies, film screenings, workshops, exhibits, concerts, forum discussions on various co-sponsored programs.",
#     "id": 61951,
#     "is_disabled": false,
#     "keywords": "Black History, Black, African, Caribbean, Afro-Latin@, Afro-Asian, African Diaspora, Culture, Theme Month",
#     "long_name": "African Heritage Month - All-University",
#     "member_count": 145,
#     "picture_url": "https://cdn3.orgsync.com/images/os-profile-pics/lwlk1o5l4rmj3qn_150.jpg?cover=1&s=100",
#     "renewed_at": "2018-07-26T03:50:09Z",
#     "name": "AHM",
#     "umbrella_id": 53830,
#     "website_url": "https://www.facebook.com/africanheritagemonthnyu"
#   },
#   {
#     "alternate_id": null,
#     "category": {
#       "id": 86050,
#       "name": "Multicultural Groups"
#     },
#     "created_at": "2013-01-02T23:03:27Z",
#     "description": "The African Students Union exists to provide a means for the meaningful discussion, exploration and celebration of all things politically, socially, and culturally African. We want to create an environment on campus where people who are educated on African topics or wish to be can come together to have fun, discuss and enjoy a variety of African dishes. ",
#     "id": 61932,
#     "is_disabled": false,
#     "keywords": "Cultural\r\nASU\r\nAfrican",
#     "long_name": "African Students Union - All-University",
#     "member_count": 480,
#     "picture_url": "https://cdn2.orgsync.com/images/os-profile-pics/13f529d9-6037-4141-bf2c-cf7e3eb38c8c.PNG?cover=1&s=100",
#     "renewed_at": "2018-11-08T18:40:24Z",
#     "name": "African Students Union",
#     "umbrella_id": 53830,
#     "website_url": "http://www.nyu.edu/clubs/asu/"
#   },
#   {
#     "alternate_id": null,
#     "category": {
#       "id": 86055,
#       "name": "Literary Groups"
#     },
#     "created_at": "2013-01-02T22:10:53Z",
#     "description": "Aftab is the literary magazine of the Islamic Center at New York University. This publication is meant to serve as a creative outlet for members of the community to express and exchange their thoughts and ideas about issues facing our community through poetry, prose, stories, essays, artwork, illustrations, photography, etc. ",
#     "id": 61670,
#     "is_disabled": false,
#     "keywords": "",
#     "long_name": "Aftab: Rays of Light - All-University",
#     "member_count": 71,
#     "picture_url": "https://cdn4.orgsync.com/images/os-profile-pics/604cpt77pleq2cj_150.jpg?cover=1&s=100",
#     "renewed_at": "2018-07-31T04:05:48Z",
#     "name": "Aftab: Rays of Light",
#     "umbrella_id": 53830,
#     "website_url": "http://www.aftabnyu.com/"
#   },
#   {
#     "alternate_id": null,
#     "category": {
#       "id": 85863,
#       "name": "Improv"
#     },
#     "created_at": "2018-02-06T19:53:12Z",
#     "description": null,
#     "id": 170724,
#     "is_disabled": false,
#     "keywords": "",
#     "long_name": "After School Improv",
#     "member_count": 1,
#     "picture_url": "/assets/icons/portals/no_org_profile_100.png",
#     "renewed_at": null,
#     "name": "ASI",
#     "umbrella_id": 78810,
#     "website_url": null
#   },
#   {
#     "alternate_id": null,
#     "category": {
#       "id": 86074,
#       "name": "Religious Groups"
#     },
#     "created_at": "2013-01-02T22:32:50Z",
#     "description": "Agape Week is a week in the Fall semester filled with events that spread the awareness of Christianity. ",
#     "id": 61840,
#     "is_disabled": false,
#     "keywords": "Agape Week, Christianity, Agape, Fall Semester, Fellowships, Fall",
#     "long_name": "Agape Week Planning Committee - Theme Week - All-University",
#     "member_count": 41,
#     "picture_url": "/assets/icons/portals/no_org_profile_100.png",
#     "renewed_at": "2018-07-17T14:58:48Z",
#     "name": "Agape Week Planning Committee",
#     "umbrella_id": 53830,
#     "website_url": "http://www.nyu.edu/clubs/agape"
#   },
#   {
#     "alternate_id": null,
#     "category": {
#       "id": 61111,
#       "name": "Service"
#     },
#     "created_at": "2016-09-28T15:02:53Z",
#     "description": null,
#     "id": 147493,
#     "is_disabled": false,
#     "keywords": "",
#     "long_name": "AHRCNYC",
#     "member_count": 1,
#     "picture_url": "/assets/icons/portals/no_org_profile_100.png",
#     "renewed_at": null,
#     "name": "AHRCNYC",
#     "umbrella_id": 102322,
#     "website_url": null
#   },
#   {
#     "alternate_id": null,
#     "category": {
#       "id": 84943,
#       "name": "Health Professions and Clinical Interests "
#     },
#     "created_at": "2016-02-24T22:34:27Z",
#     "description": null,
#     "id": 134812,
#     "is_disabled": true,
#     "keywords": "",
#     "long_name": "AIDS Awareness Society",
#     "member_count": 11,
#     "picture_url": "/assets/icons/portals/no_org_profile_100.png",
#     "renewed_at": "2016-02-26T15:26:52Z",
#     "name": "AIDS",
#     "umbrella_id": 86331,
#     "website_url": null
#   },
#   {
#     "alternate_id": null,
#     "category": {
#       "id": 86063,
#       "name": "Vocal"
#     },
#     "created_at": "2013-01-02T22:07:02Z",
#     "description": "New York University's one and only gospel choir on campus. The choir combines fellowship, music and creativity with around 40 members and the choir continues to grow every semester! If you are interested, check out our youtube channel from previous concerts...\r\n\r\n\r\nhttp://www.youtube.com/user/AUGCofNYU\r\n\r\nLike us on Facebook. . .\r\nhttps://www.facebook.com/AUGCatNYU?fref=ts\r\n\r\nAlso, no auditions! Just make sure you get to every rehearsal!",
#     "id": 61631,
#     "is_disabled": false,
#     "keywords": "gospel,choir, nyu, community, singing,no auditions,inclusive, a cappella, ",
#     "long_name": "All University Gospel Choir (co-ed choir) - All-University",
#     "member_count": 136,
#     "picture_url": "https://cdn4.orgsync.com/images/os-profile-pics/95jheri5m5nv4z0_150.jpg?cover=1&s=100",
#     "renewed_at": "2018-07-05T15:27:20Z",
#     "name": "AUGC",
#     "umbrella_id": 53830,
#     "website_url": "http://www.nyu.edu/clubs/augc"
#   },
#   {
#     "alternate_id": null,
#     "category": {
#       "id": 39877,
#       "name": "Student Council/Government"
#     },
#     "created_at": "2012-12-13T14:46:44Z",
#     "description": "ASSBAC is a sub-committee of the University Committee on Student Life and serves as the funding source for All-Square clubs. ASSBAC's mission is to assess the funding needs of All-Square clubs, advocate on behalf of All-Square clubs as related to their funding, and allocate funds to these clubs based on criteria set by the committee. ASSBAC sets policies and procedures regarding the funding process and makes the final decisions regarding allocations, reallocations, budget appeals, and requests for contingency funding.",
#     "id": 61483,
#     "is_disabled": true,
#     "keywords": "",
#     "long_name": "All-Square Student Budget Allocation Committee - UCSL",
#     "member_count": 10,
#     "picture_url": "/assets/icons/portals/no_org_profile_100.png",
#     "renewed_at": "2015-06-23T21:25:13Z",
#     "name": "ASSBAC",
#     "umbrella_id": 53830,
#     "website_url": "http://www.nyu.edu/about/leadership-university-administration/university-senate/membership/councils/student-senators-council/club-life.html"
#   },
#   {
#     "alternate_id": null,
#     "category": {
#       "id": 63317,
#       "name": "Elections"
#     },
#     "created_at": "2015-03-19T16:39:21Z",
#     "description": null,
#     "id": 111743,
#     "is_disabled": true,
#     "keywords": "",
#     "long_name": "All-University Elections",
#     "member_count": 33638,
#     "picture_url": "https://cdn2.orgsync.com/images/os-profile-pics/xzngos48p2p6knj_150.jpg?cover=1&s=100",
#     "renewed_at": "2015-07-24T19:19:19Z",
#     "name": "Elections",
#     "umbrella_id": 53830,
#     "website_url": null
#   },
#   {
#     "alternate_id": null,
#     "category": {
#       "id": 84943,
#       "name": "Health Professions and Clinical Interests "
#     },
#     "created_at": "2016-02-24T22:35:44Z",
#     "description": "AQUA is the LGBTQIA club at NYU Dentistry. Our focus is on making sure that students of all orientations and identities feel welcome in our community by serving as their home base in addition to providing opportunities for our fellow health professionals to better educate themselves on the unique challenges of medical care for members of this community of identities.",
#     "id": 134813,
#     "is_disabled": false,
#     "keywords": "LGBTQ, gay rights, LGBT, queer, LGBTQIA, ",
#     "long_name": "Allies & Queers for Understanding and Awareness",
#     "member_count": 13,
#     "picture_url": "https://cdn0.orgsync.com/images/os-profile-pics/ed4f3bznv4gms2h_150.jpg?cover=1&s=100",
#     "renewed_at": "2018-06-08T18:03:37Z",
#     "name": "AQUA",
#     "umbrella_id": 86331,
#     "website_url": "https://www.facebook.com/groups/aquanyucd/"
#   },
#   {
#     "alternate_id": null,
#     "category": {
#       "id": 86054,
#       "name": "Sorority Life"
#     },
#     "created_at": "2013-01-02T22:10:00Z",
#     "description": "The mission of Alpha Epsilon Phi Sorority is to inspire and support exemplary women dedicated to friendship and a lifelong commitment to Alpha Epsilon Phi while building on the vision of our founders.  \r\n\r\nAbove all else, Alpha Epsilon Phi inspires exemplary women who are:\r\nenriched by sisterhood and unconditional friendships, dedicated to selfless service and inspiring others, and committed to intellectual growth and personal development. \r\n",
#     "id": 61649,
#     "is_disabled": false,
#     "keywords": "alpha epsilon phi, aephi, sorority, panhellenic, recruitment, sorority recruitment, nyu sorority, nyu sororities, alpha, epsilon, phi, giraffe, green, white, sisterhood, service, philanthropy, scholarship, academic, professional, networking, alum, friendship, women, all square, giraffes, jewish, community, fun, panhel, organization, b+ foundation, andrew mcdonough b+ foundation, cancer, pediatric cancer, childhood cancer, be positive, foundation, mcdonough, sharsheret, egpaf, elizebeth glaser pediatric aids, pediatric aids, aids, breast cancer, pink",
#     "long_name": "Alpha Epsilon Phi Sorority - All-University",
#     "member_count": 143,
#     "picture_url": "https://cdn1.orgsync.com/images/os-profile-pics/uqeyj5mrhu7tdu_150.jpg?cover=1&s=100",
#     "renewed_at": "2018-12-13T20:33:28Z",
#     "name": "Alpha Epsilon Phi",
#     "umbrella_id": 53830,
#     "website_url": "http://www.nyuaephi.com"
#   },
#   {
#     "alternate_id": null,
#     "category": {
#       "id": 86054,
#       "name": "Sorority Life"
#     },
#     "created_at": "2013-01-02T22:50:08Z",
#     "description": "alpha Kappa Delta Phi is an international Asian-interest sorority with over 50 chapters located at numerous universities across the United States and in Canada. Thousands of undergraduate and alumnae sisters support the rapidly growing network of strong and successful women in the organization. alpha Kappa Delta Phi is part of the National APIA Panhellenic Association (NAPA), which it helped charter in 2006.\r\n\r\nMISSION STATEMENT\r\nalpha Kappa Delta Phi Sorority, Inc. fosters the making of successful leaders by assisting and challenging our members to reach their maximum potential. We strive to maintain the highest levels of integrity and innovation in the promotion of sisterhood, philanthropy, scholastic excellence, and Asian-Awareness in the community while creating lifelong relationships.\r\n\r\nNEW YORK UNIVERSITY CHAPTER\r\nalpha Kappa Delta Phi was founded at New York University on April 10, 1999. Since then, the NYU chapter has succeeded in making itself known on campus for embodying all aspects of the sorority on which it was founded on. With almost one hundred sisters, NYU aKDPhi has an ever-growing network of female leaders.",
#     "id": 61899,
#     "is_disabled": false,
#     "keywords": "greek life, sorority, asian, chinese, korean, thai, vietnamese, taiwanese, alpha kappa delta phi, alpha, kappa, delta, phi, purple, MGC, multicultural greek council, asian-interest, kdphi, akdphi, nyu, nyu greeks, nyu greek life, nyu akdphi",
#     "long_name": "alpha Kappa Delta Phi - All-University",
#     "member_count": 34,
#     "picture_url": "https://cdn0.orgsync.com/images/os-profile-pics/lky4smjcn70n8qz_150.jpg?cover=1&s=100",
#     "renewed_at": "2018-07-26T20:25:14Z",
#     "name": "aKDPhi",
#     "umbrella_id": 53830,
#     "website_url": "https://www.facebook.com/aKDPhiAtNYU"
#   },
#   {
#     "alternate_id": null,
#     "category": {
#       "id": 54292,
#       "name": "Business"
#     },
#     "created_at": "2014-05-12T17:33:25Z",
#     "description": "Alpha Kappa Psi is the first Professional Business Fraternity in the United States. Chartered, founded, and opened in 1904 right here at New York University, Alpha Kappa Psi has 318 active chapters across the US, and is one of the only organizations to have gone international, with three chapters in the United Kingdom, and one in Canada.\r\n\r\nFor over 106 years the brothers of Alpha Kappa Psi have constituted an elite group of driven, intelligent, and hard-working business leaders. We are proud to continue that legacy of Shaping People, Shaping Business.\r\n\r\nHere are some of our prominent alumni:\r\n\r\no Presidents Ronald Reagan and Richard Nixon\r\no Malcolm Forbes, Jr. - Founder of Forbes Magazine\r\no J. Willard Marriott - Founder of Marriott Hotels\r\no Joyce C. Hall - Founder of Hallmark Cards, Inc.\r\no Sam Walton - Founder of Wal-Mart and Sam's Club\r\n\r\nOur chapter at NYU Stern is one of the most active organizations on Stern’s campus and one of the most recognized chapters of Alpha Kappa Psi. Through professional development of our members and Stern students at large, working to strengthen the community at Stern and at NYU or by serving our local community in the city of New York we continue to strive for excellence and fulfil our mission of serving as the premier developer of principled business leaders.\r\n\r\nAbove all, Alpha Kappa Psi has taught so many of us the true meaning of friendship. Once you become a member of Alpha Kappa Psi, you are a brother for life.",
#     "id": 86560,
#     "is_disabled": false,
#     "keywords": "Business, Professional, Fraternity, Brotherhood",
#     "long_name": "Alpha Kappa Psi",
#     "member_count": 87,
#     "picture_url": "https://cdn4.orgsync.com/images/os-profile-pics/fbm54995nx7udxw_150.jpg?cover=1&s=100",
#     "renewed_at": "2018-05-06T05:16:18Z",
#     "name": "AKPsi",
#     "umbrella_id": 86332,
#     "website_url": "http://www.nyuakpsi.org"
#   },
#   {
#     "alternate_id": null,
#     "category": {
#       "id": 86074,
#       "name": "Religious Groups"
#     },
#     "created_at": "2013-01-02T22:31:03Z",
#     "description": "Alpha Omega is an on-campus Christian club working to make God accessible to all. Our goal is to discover what the Bible says about our lives as college students in the 21st century and how we can relate to it, as well as having fun along the way. We have many events throughout the semester such as our small groups called Bible Talk every Monday and Thursday. These are discussion groups in which we discuss a topic relating to our lives and see what the Bible has to say. We also have fun events on Friday, and Church Service on Wednesdays and  Sundays with the New York City Church of Christ. You do not have to be a Christian or have any experience with Christianity to come out!",
#     "id": 61799,
#     "is_disabled": false,
#     "keywords": "bible, christian, christianity, church, god, jesus christ, christ, jesus, fellowship, non-denominational, friends, friendship, alpha omega, ao, nyc church",
#     "long_name": "Alpha Omega - All-University",
#     "member_count": 40,
#     "picture_url": "https://cdn3.orgsync.com/images/os-profile-pics/d5a25739-1811-43f4-8b07-0a6abb18389f.jpg?cover=1&s=100",
#     "renewed_at": "2018-07-05T16:26:02Z",
#     "name": "Alpha Omega",
#     "umbrella_id": 53830,
#     "website_url": "https://www.facebook.com/aomanhattan"
#   },
#   {
#     "alternate_id": null,
#     "category": {
#       "id": 84943,
#       "name": "Health Professions and Clinical Interests "
#     },
#     "created_at": "2016-02-24T22:42:33Z",
#     "description": "Alpha Omega is a Jewish dental fraternity used for social events, networking and continued education. Alpha Omega is used to connect all Jewish students on campus, but encourages participation from all cultures.",
#     "id": 134827,
#     "is_disabled": false,
#     "keywords": "Jewish; kosher; Zionist; holiday; Alpha Omega; Yeshiva",
#     "long_name": "Alpha Omega at NYU College of Dentistry",
#     "member_count": 26,
#     "picture_url": "/assets/icons/portals/no_org_profile_100.png",
#     "renewed_at": "2018-06-25T15:20:13Z",
#     "name": "AO",
#     "umbrella_id": 86331,
#     "website_url": null
#   },
#   {
#     "alternate_id": null,
#     "category": {
#       "id": 85642,
#       "name": "Sorority Life"
#     },
#     "created_at": "2015-01-21T14:59:25Z",
#     "description": "Alpha Omega Epsilon is a professional and social Sorority founded in 1983 that promotes friendship, leadership, and professionalism to all members of the organization, community, and our professions. The Beta Sigma Chapter here at NYU was founded on February 23rd, 2016 with a total of 23 founding members.",
#     "id": 105622,
#     "is_disabled": false,
#     "keywords": "Social, Sorority, Professional, Professionalism, Sisterhood, Leadership, Friendship, Building Skills, Alpha Omega Epsilon, Sisters, Greek life ",
#     "long_name": "Alpha Omega Epsilon",
#     "member_count": 50,
#     "picture_url": "https://cdn4.orgsync.com/images/os-profile-pics/e12yf37vk5yniwn_150.jpg?cover=1&s=100",
#     "renewed_at": "2018-07-03T18:31:39Z",
#     "name": "AOE",
#     "umbrella_id": 89838,
#     "website_url": "http://nyualphaomegaepsil.wixsite.com/aoebetasigma"
#   },
#   {
#     "alternate_id": null,
#     "category": {
#       "id": 86053,
#       "name": "Fraternity Life"
#     },
#     "created_at": "2016-08-04T18:59:59Z",
#     "description": "Alpha Phi Alpha Fraternity Incorporated develops leaders, promotes brotherhood and academic excellence while providing service and advocacy for our communities. The Upsilon Upsilon Chapter of Alpha Phi Alpha Fraternity, Inc. was chartered on May 24, 2016 on the campus of New York University by Chevaun Samuels, Nathaniel Simmons, Orville Edwards, Kwame Assoku, Ta' Fisher, Romel Williams, Tamir Griffin and Udensi Kalu. ",
#     "id": 143392,
#     "is_disabled": false,
#     "keywords": "Fraternity, Brotherhood, Service, Leadership, Scholarship, Black Men",
#     "long_name": "Alpha Phi Alpha Fraternity, Inc. - All-University",
#     "member_count": 10,
#     "picture_url": "https://cdn3.orgsync.com/images/os-profile-pics/c02aaef0-51b6-425f-a385-ef56e845c734.png?cover=1&s=100",
#     "renewed_at": "2018-07-15T19:07:21Z",
#     "name": "Alpha",
#     "umbrella_id": 53830,
#     "website_url": "https://www.facebook.com/NYYUAlphas/"
#   },
#   {
#     "alternate_id": null,
#     "category": {
#       "id": 86053,
#       "name": "Fraternity Life"
#     },
#     "created_at": "2013-01-02T22:12:20Z",
#     "description": "Alpha Phi Delta Fraternity was founded at Syracuse University by seven young men with Italian roots. Originally founded as a secret society, it has now evolved into one of America's most unique fraternities with over 20,000 lifelong members. Alpha Phi Delta is also the largest fraternity in the Tri-State NY area, with over 10 chapters that are only a train ride away!\r\n\r\nAt the Theta Beta chapter in NYU, Alpha Phi Delta prides itself with academic excellence and integrity from all brothers. Many of the brothers are some of the most outstanding students on their campuses, pursuing careers in politics, law, business, and the liberal arts, among other professions. Brothers have also been commended and acknowledged by the school for their many philanthropy related events, including but not limited to Relay for Life participation, Habitat for Humanity and a campus wide food and clothes drive. There have also been many instances where the chapter would also work with other student organizations on campus in philanthropic activities, such as fundraising for the Leukemia and Lymphoma Society.\r\n\r\nIf any are interested in joining, or merely checking out Alpha Phi Delta, please send us an email or a message on our Facebook website, and meet with us during Rush Week. It will be an opportunity to meet with the brothers, as well as a chance for us to get to know you better. Bring your friends to have fun with us, hang out, and find out if you have what it takes to become an Alpha man in our Fraternity.",
#     "id": 61704,
#     "is_disabled": false,
#     "keywords": "Social, Fraternity, Brotherhood, Brothers, Activity, Clubs, Alpha, Phi, Delta, Brother, Greek, Italian Heritage.",
#     "long_name": "Alpha Phi Delta - All-University",
#     "member_count": 10,
#     "picture_url": "https://cdn3.orgsync.com/images/os-profile-pics/rba70xm4czmyi7q_150.jpg?cover=1&s=100",
#     "renewed_at": "2018-10-02T17:13:01Z",
#     "name": "Alpha Phi Delta",
#     "umbrella_id": 53830,
#     "website_url": "https://www.facebook.com/APDNYU"
#   },
#   {
#     "alternate_id": null,
#     "category": {
#       "id": 86046,
#       "name": "Service/Volunteer Work"
#     },
#     "created_at": "2013-01-02T22:20:53Z",
#     "description": "Alpha Phi Omega is a national co-ed fraternity dedicated to community service. Today, there are more than 17,000 male and female student members at 366 college campuses nationwide. We are proud to be the largest Greek letter fraternity. \r\n\r\nOur mission is to develop leadership through service, to promote friendship, and to provide service to humanity. \r\n\r\nWe look for those who are passionate about community service to join our fraternity. Our chapter, Beta Iota, focuses on the needs of others in New York City. Brothers participate in activities that include park clean-ups, bringing food to homeless shelters, and volunteering with children in afterschool programs. There are no restrictions on our list of community service activities, and Brothers are encouraged to offer ideas for projects. ",
#     "id": 61726,
#     "is_disabled": false,
#     "keywords": "community service, fraternity, fellowship, leadership, alumni, networking",
#     "long_name": "Alpha Phi Omega - National Service Fraternity - All-University",
#     "member_count": 380,
#     "picture_url": "https://cdn4.orgsync.com/images/os-profile-pics/njf1yd3g49nduws_150.jpg?cover=1&s=100",
#     "renewed_at": "2018-07-13T20:41:35Z",
#     "name": "APO",
#     "umbrella_id": 53830,
#     "website_url": "http://www.aponyu.org"
#   },
#   {
#     "alternate_id": null,
#     "category": {
#       "id": 86054,
#       "name": "Sorority Life"
#     },
#     "created_at": "2013-01-02T22:32:32Z",
#     "description": "This is the New York University (Delta Phi) chapter of Alpha Sigma Tau, a national Panhellenic sorority founded in 1899. Beauty of Spirit. Fulfillment of Self. Exceptional Sisterhood. Anchored for Life.",
#     "id": 61833,
#     "is_disabled": false,
#     "keywords": "sorority, greek life, philanthropy, academics, service, sisterhood, scholarship",
#     "long_name": "Alpha Sigma Tau Sorority - All-University",
#     "member_count": 107,
#     "picture_url": "https://cdn3.orgsync.com/images/os-profile-pics/2464b679-db96-4203-849d-5ef89025bf55.JPG?cover=1&s=100",
#     "renewed_at": "2018-07-31T20:26:39Z",
#     "name": "AST",
#     "umbrella_id": 53830,
#     "website_url": "http://nyu.alphasigmatau.org/"
#   },
#   {
#     "alternate_id": null,
#     "category": {
#       "id": 60613,
#       "name": "Upperclass"
#     },
#     "created_at": "2014-11-20T20:26:19Z",
#     "description": "Located in the heart of East Village, Alumni Hall has approximately 450 upperclass and graduate residents. We share our programs and staff with our East Village neighbors in the Green House at 7th Street. Together these two buildings make up the 7A Partnership.\r\n\r\nAlumni consists of 100% single bedrooms - every resident has a bedroom to themselves and shares a suite with 1-3 other suitemates. Bedrooms have a bed, desk, closet, and dresser. Common areas include a table with 2 chairs, fridge, stove, sink, and cabinets. Alumni has two recently renovated lounges: a TV lounge with a pool table, and a study lounge with plenty of space. There are also smaller study lounges on floors 2, 3, 4, 5, 6, 13, 14, and 15. Laundry is in the basement.\r\n\r\nThere are plenty of activities to get involved with at Alumni. The 7A Partnership Hall Council is a great opportunity that allows you to become a leader in the community, by either running for elected office or serving as a floor representative.\r\n\r\nThe 14 RAs and hall council plans a variety of programs for the buildings and it is an excellent way for residents to get to know one another. Also, there are programs planned by the Faculty Fellows in Residence, Jim Calder and Joan Harmon. These events range from Broadway shows, food tastings, to discussions with distinguished alumni.",
#     "id": 102680,
#     "is_disabled": false,
#     "keywords": "Apartment",
#     "long_name": "Alumni & 7th Street",
#     "member_count": 1146,
#     "picture_url": "https://cdn4.orgsync.com/images/os-profile-pics/b2e2akb8lkifjli_150.jpg?cover=1&s=100",
#     "renewed_at": "2014-11-21T14:43:47Z",
#     "name": "7A",
#     "umbrella_id": 89840,
#     "website_url": "http://www.nyu.edu/life/living-at-nyu/on-campus-living/explore-the-residencehalls/alumni-hall.html"
#   },
#   {
#     "alternate_id": null,
#     "category": {
#       "id": 84943,
#       "name": "Health Professions and Clinical Interests "
#     },
#     "created_at": "2016-02-24T22:36:05Z",
#     "description": "The American Academy of Pediatric Dentistry student chapter is dedicated to engaging dental students interested in pediatric dentistry. ",
#     "id": 134814,
#     "is_disabled": false,
#     "keywords": "NYUCD, AAPD, pediatrics, kids, dental care",
#     "long_name": "American Academy of Pediatric Dentistry Student Chapter",
#     "member_count": 24,
#     "picture_url": "/assets/icons/portals/no_org_profile_100.png",
#     "renewed_at": "2018-11-19T20:33:44Z",
#     "name": "AAPD",
#     "umbrella_id": 86331,
#     "website_url": null
#   },
#   {
#     "alternate_id": null,
#     "category": {
#       "id": 85671,
#       "name": "Engineering"
#     },
#     "created_at": "2014-11-14T18:09:32Z",
#     "description": "The American Association of Blacks in Energy (AABE) aims to benefit the NYU School of Engineering community by bringing awareness of the opportunities and challenges posed in the energy field while solving these challenges through membership, practical knowledge and experiences. ",
#     "id": 102367,
#     "is_disabled": false,
#     "keywords": "Energy, engineering, business, engineer, science, technology, stem, diversity",
#     "long_name": "American Association of Blacks in Energy (AABE)",
#     "member_count": 128,
#     "picture_url": "https://cdn2.orgsync.com/images/os-profile-pics/onufs6w3l9s2o22_150.jpg?cover=1&s=100",
#     "renewed_at": "2018-09-17T14:11:42Z",
#     "name": "AABE",
#     "umbrella_id": 89838,
#     "website_url": "http://nyuaabe.org/"
#   },
#   {
#     "alternate_id": null,
#     "category": {
#       "id": 85072,
#       "name": "Chemistry"
#     },
#     "created_at": "2017-12-21T16:15:34Z",
#     "description": "The American Chemical Society at NYU is a undergraduate and graduate chapter of the national organization. We are dedicated to supporting aspiring Chemists and Biochemists as well as Chemistry enthusiasts through a host of networking, research, and professional development events. In addition, we engage in public outreach projects as a form of community service.",
#     "id": 169557,
#     "is_disabled": false,
#     "keywords": "Chemistry, Professional Development, Networking, STEM, Industry, Academic",
#     "long_name": "American Chemical Society",
#     "member_count": 130,
#     "picture_url": "https://cdn1.orgsync.com/images/os-profile-pics/84f60367-c208-4378-ae55-01ba8d48ff61.png?cover=1&s=100",
#     "renewed_at": "2018-08-01T17:36:51Z",
#     "name": "ACS",
#     "umbrella_id": 106007,
#     "website_url": "https://www.facebook.com/nyuacs/"
#   },
#   {
#     "alternate_id": null,
#     "category": {
#       "id": 84943,
#       "name": "Health Professions and Clinical Interests "
#     },
#     "created_at": "2016-02-24T22:37:24Z",
# ...
#     "id": 163346,
#     "is_disabled": false,
#     "keywords": "Mentorship, Women",
#     "long_name": "WoMentorship Program",
#     "member_count": 65,
#     "picture_url": "https://cdn2.orgsync.com/images/os-profile-pics/jhd9rsa569l8j9v_150.jpg?cover=1&s=100",
#     "renewed_at": "2017-08-09T16:32:02Z",
#     "name": "WoM",
#     "umbrella_id": 89838,
#     "website_url": "http://engineering.nyu.edu/academics/women-engineering"
#   },
#   {
#     "alternate_id": null,
#     "category": {
#       "id": 86049,
#       "name": "Cultural Groups"
#     },
#     "created_at": "2018-03-19T19:37:56Z",
#     "description": "Workmen’s Circle at NYU (WCNYU) is a secular organization focused on the preservation of Jewish culture, Yiddish language, and the promotion of economic and educational justice. WCNYU seeks to foster relationships between community members through social activism events such as marches and protests, educational seminars from speakers representing different coalitions, and through Jewish cultural traditions including shabbat and seders. ",
#     "id": 172225,
#     "is_disabled": false,
#     "keywords": "workmen's, workmen, workman, circle, workmen's circle, wc, wcnyu, wcny, jewish, jew, judaism, activism, religious, cultural, socialism, labor, union, unions, yiddish",
#     "long_name": "Workmen's Circle at NYU - All-University",
#     "member_count": 29,
#     "picture_url": "https://cdn2.orgsync.com/images/os-profile-pics/2b07e70a-ae0c-4500-a383-c36948b7ed9e.png?cover=1&s=100",
#     "renewed_at": "2018-07-10T17:28:58Z",
#     "name": "WCNYU",
#     "umbrella_id": 53830,
#     "website_url": "https://circle.org/"
#   },
#   {
#     "alternate_id": null,
#     "category": {
#       "id": 86046,
#       "name": "Service/Volunteer Work"
#     },
#     "created_at": "2013-01-02T22:50:46Z",
#     "description": "World Faith’s primary goal is to de-incentivize violence. We do this by countering narratives of \"otherism\" by encouraging humanization through volunteering together.\r\n\r\nBy mobilizing religiously diverse youth to design and implement development projects, we counter each driver of violence. We break down the narrative of conflict by creating opportunities for young people to recognize the humanity of their fellow youth while volunteering together.",
#     "id": 61914,
#     "is_disabled": false,
#     "keywords": "world, faith, community, service, religion, diversity, youth, global, volunteer",
#     "long_name": "World Faith - All-University",
#     "member_count": 65,
#     "picture_url": "https://cdn2.orgsync.com/images/os-profile-pics/wfkemt0ha1qpm9z_150.jpg?cover=1&s=100",
#     "renewed_at": "2018-07-26T03:49:23Z",
#     "name": "World Faith",
#     "umbrella_id": 53830,
#     "website_url": "http://www.nyu.edu/clubs/worldfaith"
#   },
#   {
#     "alternate_id": null,
#     "category": {
#       "id": 84943,
#       "name": "Health Professions and Clinical Interests "
#     },
#     "created_at": "2016-02-24T22:52:53Z",
#     "description": "Xi Psi Phi Fraternity is a fellowship, chosen from among those who have decided upon a career in the profession of dentistry. The fraternity declares that the fellowship established through the years is based on a simple understanding which honors these principles; knowledge, morality, friendship. The Xi Psi Phi Beta Chapter has been a part of NYU College of Dentistry's history, going as far back as 1893 when it was the New York College of Dentistry before joining NYU in 1925. Our chapter is dedicated to the education of its members and the greater public in matters pertaining to oral health and the art of living well.",
#     "id": 134844,
#     "is_disabled": false,
#     "keywords": "Academic, identity, mentorship, leadership, friendship, hospitality, service, volunteerism, dentistry, greek, greek life, dental fraternity",
#     "long_name": "Xi Psi Phi Fraternity",
#     "member_count": 53,
#     "picture_url": "https://cdn4.orgsync.com/images/os-profile-pics/4a3c311f-2998-45dd-9634-725fa1338473.jpeg?cover=1&s=100",
#     "renewed_at": "2018-06-25T15:21:02Z",
#     "name": "ZIPS",
#     "umbrella_id": 86331,
#     "website_url": null
#   },
#   {
#     "alternate_id": null,
#     "category": {
#       "id": 35915,
#       "name": "Athletic Club"
#     },
#     "created_at": "2011-12-13T20:19:22Z",
#     "description": "Join us for a weekly yoga class. Class is usually held on Wednesdays at 4:45pm. Open to all levels! \r\n",
#     "id": 46324,
#     "is_disabled": true,
#     "keywords": "",
#     "long_name": "Yoga Club",
#     "member_count": 56,
#     "picture_url": "https://cdn3.orgsync.com/images/os-profile-pics/8500djqcxdj7ab_150.jpg?cover=1&s=100",
#     "renewed_at": "2013-02-01T21:15:12Z",
#     "name": "Yoga",
#     "umbrella_id": 43082,
#     "website_url": "http://nyuschoolofmedicine.orgsync.com/org/yogaclub46324"
#   },
#   {
#     "alternate_id": null,
#     "category": {
#       "id": 35743,
#       "name": "Clinical Interest Club"
#     },
#     "created_at": "2011-12-13T20:19:34Z",
#     "description": "The Young at Heart Club intends to ignite interest in Geriatrics in the student community at NYU as well as interact with and care for the older adults in the New York Area. We aim to have a variety of educational events built around learning to care for older adults. Also, our group has a commitment to assisting the older adult population, through education and interpersonal interaction. We intend to foster a spirit of enthusiasm and compassion in our students who will be caring for this expanding population of patients in our health care system.",
#     "id": 46325,
#     "is_disabled": false,
#     "keywords": "geriatrics, elderly, senior citizens, Gouverneur Nursing Home, end-stage disease, clinical medicine",
#     "long_name": "Young At Heart",
#     "member_count": 28,
#     "picture_url": "https://cdn0.orgsync.com/images/os-profile-pics/iha4xhppkrjqxq_150.jpg?cover=1&s=100",
#     "renewed_at": "2016-01-12T17:52:55Z",
#     "name": "Young at Heart",
#     "umbrella_id": 43082,
#     "website_url": null
#   },
#   {
#     "alternate_id": null,
#     "category": {
#       "id": 86068,
#       "name": "Political Groups"
#     },
#     "created_at": "2018-03-08T17:10:09Z",
#     "description": "NYU YDSA meets weekly, alternating between (a) organizing meetings, where we discuss and plan strategic campaigns and (b) political education meetings, where we reflect on a reading or film. Young Democratic Socialists at NYU is NYU's chapter of the Democratic Socialists of America, America's largest socialist organization. We at NYU YDSA believe that a group to discuss, learn, and advocate for a different kind of society is necessary in the face of the historical moment we are living through. As democratic socialists, we believe that both the economy and society should be run democratically to meet human needs, not to make profits for a few. We are a political and activist organization, not a party; we are a big-tent organization that treats politics as a learning experience rather than a dogma; we use a variety of tactics, from legislative to direct action, to fight for reforms that empower working people. NYU's chapter will draw from the breadth of ideas and experience of the national organization, while speaking to our concerns as students located in one of the most progressive and unequal cities in the nation. This is an urgent time, and we want an open and inclusive space for students at NYU to hear and debate new political ideas, to learn about activism and how different struggles can move forward together, and to support each other and all those who lose out from the current order.",
#     "id": 171928,
#     "is_disabled": false,
#     "keywords": "Politics, Socialism, Activism ",
#     "long_name": "Young Democratic Socialists of America at NYU - All-University",
#     "member_count": 66,
#     "picture_url": "/assets/icons/portals/no_org_profile_100.png",
#     "renewed_at": "2018-07-28T00:38:11Z",
#     "name": "YDSA at NYU",
#     "umbrella_id": 53830,
#     "website_url": null
#   },
#   {
#     "alternate_id": null,
#     "category": {
#       "id": 86074,
#       "name": "Religious Groups"
#     },
#     "created_at": "2013-01-02T23:06:38Z",
#     "description": "Vision \r\n\r\nYEF NYU aspires to be a community of Christ followers who, with deep love for the word of God, are purpose driven for God’s kingdom; to raise disciples and leaders who would impact the entire campus with the values of the gospel; and to encourage the Christian community to unite as one body of Christ.\r\n\r\nMission \r\n\r\nYEF NYU seeks to constantly present the values and life of gospel of Jesus Christ through Bible studies, fellowships, prayers, active outreach, as well as sharing of everyday life on and beyond campus.",
#     "id": 61943,
#     "is_disabled": false,
#     "keywords": "Fellowship, Christianity, Jesus Christ, Word of God, Community, Bible Study, Christian fellowship, Christian, praise and worship, events",
#     "long_name": "Youth Evangelical Fellowship - All-University",
#     "member_count": 50,
#     "picture_url": "https://cdn0.orgsync.com/images/os-profile-pics/hk47w5sel4q4c0w_150.jpg?cover=1&s=100",
#     "renewed_at": "2018-07-20T02:56:19Z",
#     "name": "YEF",
#     "umbrella_id": 53830,
#     "website_url": "http://www.nyu.edu/club/evangelical.fellowship"
#   },
#   {
#     "alternate_id": null,
#     "category": {
#       "id": 83719,
#       "name": "Academic"
#     },
#     "created_at": "2018-07-06T18:47:43Z",
#     "description": "The purpose of Youth Mappers NYU shall be to grant students the opportunity to improve skills in the field of mapping and create open geographic data and analyses that address locally defined development challenges worldwide. Our vision is to cultivate a generation of young people to become leaders in creating resilient communities and empowering them to define their world by mapping it. \r\nThe organization will strive to exchange and collaborate with other Youth Mapper chapters and youth groups worldwide while also offering themselves as a resource and service to New York University student organizations to add value through mapping.  ",
#     "id": 174208,
#     "is_disabled": false,
#     "keywords": "technology, humanitarian",
#     "long_name": "YouthMappers",
#     "member_count": 6,
#     "picture_url": "https://cdn2.orgsync.com/images/os-profile-pics/59d9d830-8f24-4bd1-8660-da7b87b37efc.png?cover=1&s=100",
#     "renewed_at": "2018-10-16T23:09:27Z",
#     "name": "NYU Youth Mappers",
#     "umbrella_id": 171308,
#     "website_url": null
#   },
#   {
#     "alternate_id": null,
#     "category": {
#       "id": 86053,
#       "name": "Fraternity Life"
#     },
#     "created_at": "2013-01-02T22:34:45Z",
#     "description": "Established in 1903, the Gamma Chapter at New York University is the oldest active chapter of Zeta Beta Tau Fraternity. The Fraternity's success is guided by its principles of intellectual awareness, social responsibility, integrity and brotherly love.\r\n\r\nBack-to-back ('17,'18) winners of NYU's Greek Week tournament, the Gamma chapter has over 60 active brothers and is the predominant fraternity on campus. Outside of curating a flurrying social scene, Brothers work tirelessly year-round with corporations, charities, and the University to cultivate the Fraternity's campus-wide mandate.",
#     "id": 61878,
#     "is_disabled": false,
#     "keywords": "Fraternity, Social, Zeta Beta Tau ",
#     "long_name": "Zeta Beta Tau - All-University",
#     "member_count": 57,
#     "picture_url": "https://cdn4.orgsync.com/images/os-profile-pics/qn7o173d5mog3of_150.jpg?cover=1&s=100",
#     "renewed_at": "2018-08-16T17:54:38Z",
#     "name": "Zeta Beta Tau",
#     "umbrella_id": 53830,
#     "website_url": "https://zbtnyu.org/"
#   },
#   {
#     "alternate_id": null,
#     "category": {
#       "id": 86053,
#       "name": "Fraternity Life"
#     },
#     "created_at": "2013-01-02T22:31:32Z",
#     "description": "Follow our news and updates at www.facebook.com/nyuzete and www.nyuzetapsi.com\r\n\r\nBecoming a Zete (pronounced \"Zate\") will be a decision you will never regret: four great years of fun, excitement, challenge, leadership, and lifelong brotherhood through thick and thin. For our brothers, we are the source of all knowledge NOT taught in a classroom, and we provide the edge, opportunities, and resources you need to succeed in school, in business, and most importantly - in life.\r\n\r\nZeta Psi is one of the oldest social fraternities in the United States, founded by Freemasons in 1847 here at NYU - 165 years of heritage, tradition, and enduring success. Through our extensive alumni network, our active brothers have developed connections with such companies as: Goldman Sachs, J.P. Morgan, Morgan Stanley, Credit Suisse, Barclays, Columbia Pictures, Sony Pictures, Vanguard Management Group, countless law firms and hospitals throughout New York and Washington D.C. We work hard to help our new brothers find their ideal internships early on in their career at NYU.\r\n\r\nFrom winning intramural sports championships to maintaining one of the highest aggregate chapter GPAs on campus (3.5), to participating in many philanthropic efforts and having frequent social events throughout the year, Zeta Psi prides itself on being one of the most diverse groups at NYU. Come out to rush week to meet some of our brothers and see what we're all about, beginning in September.\r\n\r\n",
#     "id": 61811,
#     "is_disabled": false,
#     "keywords": "Fraternities, Frats, Fraternity, Frat, Sports, Brothers, Brotherhood, Zete, Zetes, Zeta Psi, Philanthropy, Service, Social",
#     "long_name": "Zeta Psi Fraternity of North America - All-University",
#     "member_count": 81,
#     "picture_url": "https://cdn4.orgsync.com/images/os-profile-pics/xc3p3u0usaokfg_150.jpg?cover=1&s=100",
#     "renewed_at": "2018-07-31T18:15:49Z",
#     "name": "Zeta Psi Fraternity",
#     "umbrella_id": 53830,
#     "website_url": "http://www.nyuzetapsi.com"
#   },
#   {
#     "alternate_id": null,
#     "category": {
#       "id": 86054,
#       "name": "Sorority Life"
#     },
#     "created_at": "2013-01-02T23:07:02Z",
#     "description": "The objective of Zeta Tau Alpha shall be to intensify friendship, promote happiness among its members, and in every way to create such sentiments, to perform such deeds, and to mould such opinions as will conduce to the building up of a nobler and purer womanhood in the world.",
#     "id": 61949,
#     "is_disabled": false,
#     "keywords": "sorority, fraternity, Zeta, Tau, Alpha, ZTA",
#     "long_name": "Zeta Tau Alpha - All-University",
#     "member_count": 146,
#     "picture_url": "https://cdn4.orgsync.com/images/os-profile-pics/5312cf9f-aa6e-4a4e-a8b6-8f0998c2ce24.jpg?cover=1&s=100",
#     "renewed_at": "2018-12-13T15:37:39Z",
#     "name": "ZTA",
#     "umbrella_id": 53830,
#     "website_url": "http://nyu.zetataualpha.org"
#   },
#   {
#     "alternate_id": null,
#     "category": {
#       "id": 86049,
#       "name": "Cultural Groups"
#     },
#     "created_at": "2016-11-17T20:12:55Z",
#     "description": "¡Viva Perú! is a cultural organization that is all inclusive. Our goal is to celebrate Peruvian and Andean culture and share it with those who are interested. We want to create a familial space for many who come abroad and still miss an aspect of home. We will also discuss issues, policies, and situations that arise in the region because all history, recent or old, is part of the cultural transformation. ",
#     "id": 151502,
#     "is_disabled": false,
#     "keywords": "Cultural, latino,latina,latinx, Peru, food, policies, politics, social, service, ",
#     "long_name": "¡Viva Perú! - All-University",
#     "member_count": 102,
#     "picture_url": "https://cdn2.orgsync.com/images/os-profile-pics/bpfk3sq0vrdmjsy_150.jpg?cover=1&s=100",
#     "renewed_at": "2018-07-13T08:15:16Z",
#     "name": "Viva",
#     "umbrella_id": 53830,
#     "website_url": null
#   }
# ]
